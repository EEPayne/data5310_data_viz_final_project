# %%
import pandas as pd
import geopandas as gpd
from permits_data_cleaner import clean_permits_data

cleaned = clean_permits_data('data/Building_Permits_20251125.csv')
cleaned.head()
# Out:
# c:\Users\ellin\MSDS\DATA5310_Data_Viz\final_project\permits_data_cleaner.py:32: DtypeWarning: Columns (25,26,27,28,30,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_path)
#     PermitNum           PermitClass PermitClassMapped  \
# 0  3001776-EX            Commercial   Non-Residential
# 1  3002256-EX  Single Family/Duplex       Residential
# 2  3002287-EX  Single Family/Duplex       Residential
# 3  3003446-EX            Industrial   Non-Residential
# 4  3003449-EX           Multifamily       Residential
#
#                                     PermitTypeMapped  \
# 0  ECA and Shoreline Exemption/Street Improvement...
# 1  ECA and Shoreline Exemption/Street Improvement...
# 2  ECA and Shoreline Exemption/Street Improvement...
# 3  ECA and Shoreline Exemption/Street Improvement...
# 4  ECA and Shoreline Exemption/Street Improvement...
#
#                             PermitTypeDesc  \
# 0  Environmentally Critical Area Exemption
# 1  Environmentally Critical Area Exemption
# 2  Environmentally Critical Area Exemption
# 3                      Shoreline Exemption
# 4  Environmentally Critical Area Exemption
#
#                                          Description  EstProjectCost  \
# 0  Exception/Exemption Request for: Land Use Appl...             NaN
# 1  Exception/Exemption Request for: CANCELLED 3/8...             NaN
# 2  Exception/Exemption Request for: Land Use Appl...             NaN
# 3  Exception/Exemption Request for: CANCELLED 3/2...             NaN
# 4  Exception/Exemption Request for: CANCELED PER ...             NaN
#
#   AppliedDate ReadyToIssueDate IssuedDate  ...          OriginalAddress1  \
# 0         NaN              NaN        NaN  ...       2701 EASTLAKE AVE E
# 1         NaN              NaN        NaN  ...           7203 35TH AVE S
# 2         NaN              NaN        NaN  ...        9714 RAINIER AVE S
# 3         NaN              NaN        NaN  ...  3801 EAST MARGINAL WAY S
# 4         NaN              NaN        NaN  ...          2115 NE 130TH ST
#
#   OriginalCity OriginalState OriginalZip   Latitude   Longitude  \
# 0      Seattle            WA     98102.0  47.644647 -122.326104
# 1      Seattle            WA     98118.0  47.537680 -122.288860
# 2      Seattle            WA     98118.0  47.516509 -122.253960
# 3      Seattle            WA     98134.0  47.568529 -122.340463
# 4      Seattle            WA     98125.0  47.721691 -122.305592
#
#    TotalDaysPlanReview  NumberReviewCycles  Zoning topic
# 0                  NaN                 0.0     NaN  <NA>
# 1                  NaN                 NaN     NaN  <NA>
# 2                  NaN                 0.0     NaN  <NA>
# 3                  NaN                 NaN     NaN  <NA>
# 4                  NaN                 NaN     NaN  <NA>
#
# [5 rows x 23 columns]

# %%
cleaned.EstProjectCost.astype('float')
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 185862       5500.0
# 185863    2655216.0
# 185864     545457.0
# 185865      25978.0
# 185866      55650.0
# Name: EstProjectCost, Length: 184862, dtype: float64

# %%
cleaned['OriginalCity'].unique()
# Out:
# array(['Seattle', nan, 'King county', 'Seatlle', 'Tukwila'], dtype=object)

# %%
cleaned['topic']
# Out:
# 0             <NA>
# 1             <NA>
# 2             <NA>
# 3             <NA>
# 4             <NA>
#             ...
# 185862    retrofit
# 185863        <NA>
# 185864        <NA>
# 185865        <NA>
# 185866        <NA>
# Name: topic, Length: 184862, dtype: object

# %%
(cleaned['topic'] == 'retrofit').sum()
# Out:
# np.int64(3651)
