# %%
import pandas as pd
import geopandas as gpd
from permits_data_cleaner import clean_permits_data

cleaned = clean_permits_data('data/Building_Permits_20251125.csv')
cleaned.head()
# Out:
# c:\Users\ellin\MSDS\DATA5310_Data_Viz\final_project\permits_data_cleaner.py:39: DtypeWarning: Columns (25,26,27,28,30,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_path)
#     PermitNum           PermitClass PermitClassMapped  \
# 0  3001776-EX            Commercial   Non-Residential
# 1  3002256-EX  Single Family/Duplex       Residential
# 2  3002287-EX  Single Family/Duplex       Residential
# 3  3003446-EX            Industrial   Non-Residential
# 4  3003449-EX           Multifamily       Residential
#
#                                     PermitTypeMapped  \
# 0  ECA and Shoreline Exemption/Street Improvement...
# 1  ECA and Shoreline Exemption/Street Improvement...
# 2  ECA and Shoreline Exemption/Street Improvement...
# 3  ECA and Shoreline Exemption/Street Improvement...
# 4  ECA and Shoreline Exemption/Street Improvement...
#
#                             PermitTypeDesc  \
# ...

# %%
cleaned.columns[[25,26,27,28,30,32]]
# Out:
# Index(['TotalDaysPlanReview', 'DaysInitialPlanReview', 'DaysPlanReviewCity',
#        'DaysOutCorrections', 'InitialReviewCompleteDate',
#        'DaysIssuePermitCity'],
#       dtype='object')

# %%
cleaned.EstProjectCost.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cleaned.EstProjectCost.astype('float')
#
# File c:\Users\ellin\MSDS\DATA5310_Data_Viz\data5310_env\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File c:\Users\ellin\MSDS\DATA5310_Data_Viz\data5310_env\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...
