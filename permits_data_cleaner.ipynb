# %%
import pandas as pd
import geopandas as gpd
from permits_data_cleaner import clean_permits_data
import os

data_dir = os.path.join(os.getcwd(), 'data')
permits_path = os.path.join(data_dir, 'Building_Permits_20251125.csv')
liquefaction_areas_path = os.path.join(data_dir, 'ECA_LiquefactionProneAreas.geojson')
slide_areas_path = os.path.join(data_dir, 'ECA_PotentialSlideAreas.geojson')
cras_path = os.path.join(data_dir, 'seattle_community_reporting_areas.geojson')

cleaned = clean_permits_data(permits_path,
                             liquefaction_areas_path=liquefaction_areas_path,
                             slide_areas_path=slide_areas_path, cras_path=cras_path)
cleaned.head()
# Out:
# c:\Users\ellin\MSDS\DATA5310_Data_Viz\final_project\permits_data_cleaner.py:41: DtypeWarning: Columns (25,26,27,28,30,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_path)
# Adding columns for slide risk, liquefaction risk, and community reporting areas.
#     PermitNum           PermitClass PermitClassMapped  \
# 0  3001776-EX            Commercial   Non-Residential
# 1  3002256-EX  Single Family/Duplex       Residential
# 2  3002287-EX  Single Family/Duplex       Residential
# 3  3003446-EX            Industrial   Non-Residential
# 4  3003449-EX           Multifamily       Residential
#
#                                     PermitTypeMapped  \
# 0  ECA and Shoreline Exemption/Street Improvement...
# 1  ECA and Shoreline Exemption/Street Improvement...
# 2  ECA and Shoreline Exemption/Street Improvement...
# 3  ECA and Shoreline Exemption/Street Improvement...
# 4  ECA and Shoreline Exemption/Street Improvement...
#
# ...

# %%
cleaned['cra_no'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ellin\MSDS\DATA5310_Data_Viz\data5310_env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cra_no'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ...

# %%
cleaned['OriginalCity'].unique()
# Out:
# array(['Seattle', nan, 'King county', 'Seatlle', 'Tukwila'], dtype=object)

# %%
(cleaned['topic'] == 'retrofit').sum()
# Out:
# np.int64(4509)

# %%
cleaned[(cleaned['topic'] == 'retrofit')][['Latitude', 'Longitude']].isna().sum(axis=0)
# Out:
# Latitude     0
# Longitude    0
# dtype: int64
